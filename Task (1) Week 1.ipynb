# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
df = pd.read_csv(r'/Users/abdullahg/Downloads/Task 1/Task (1) Dataset.csv')

# %% [markdown]
# ### Handle Missing Values

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12309   9:05:00      Friday              31-50        Female
# 12312  18:00:00      Sunday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 1      Junior high school                Employee         Above 10yr
# 3      Junior high school                Employee             5-10yr
# ...

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
#checking the missing data
df.isna().sum()
#droping columns that has a lot of missing data
df1=df.drop(columns='Defect_of_vehicle')
df2=df1.drop(columns='Service_year_of_vehicle')
df3 = df2.drop(columns='Work_of_casuality')
df4 = df3.drop(columns='Fitness_of_casuality')
df =df4.dropna()

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8439 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         8439 non-null   object
#  1   Day_of_week                  8439 non-null   object
#  2   Age_band_of_driver           8439 non-null   object
#  3   Sex_of_driver                8439 non-null   object
#  4   Educational_level            8439 non-null   object
#  5   Vehicle_driver_relation      8439 non-null   object
#  6   Driving_experience           8439 non-null   object
#  7   Type_of_vehicle              8439 non-null   object
#  8   Owner_of_vehicle             8439 non-null   object
#  9   Area_accident_occured        8439 non-null   object
#  10  Lanes_or_Medians             8439 non-null   object
#  11  Road_allignment              8439 non-null   object
#  12  Types_of_Junction            8439 non-null   object
# ...

# %%
#-checking if there inconsistent data
df['Day_of_week'].unique()
df['Sex_of_casualty'].unique()
df['Age_band_of_driver'].unique()

#-replacing the inconsistent with the mode

df['Sex_of_casualty'].describe()
df['Sex_of_casualty']=df['Sex_of_casualty'].replace('na','Male')

df['Age_band_of_driver'].describe()
df['Age_band_of_driver']=df['Age_band_of_driver'].replace('Unknown','18-30')
# Out:
# /var/folders/1n/yqq3qhrn1nb3vy_qshmmw_n80000gn/T/ipykernel_5080/1630728880.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex_of_casualty']=df['Sex_of_casualty'].replace('na','Male')
# /var/folders/1n/yqq3qhrn1nb3vy_qshmmw_n80000gn/T/ipykernel_5080/1630728880.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_band_of_driver']=df['Age_band_of_driver'].replace('Unknown','18-30')

# %%
#-checking if there inconsistent data
df['Sex_of_driver'].unique()
df['Educational_level'].unique()
df['Vehicle_driver_relation'].unique()
df['Driving_experience'].unique()
df['Type_of_vehicle'].unique()

#-replacing the inconsistent with the mode

df['Sex_of_driver'].describe()
df['Sex_of_driver']=df['Sex_of_driver'].replace('Unknown','Male')

df['Educational_level'].describe()
df['Educational_level']=df['Educational_level'].replace('Unknown','Junior high school')

df['Vehicle_driver_relation'].describe()
df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].replace('Unknown','Employee')

df['Driving_experience'].describe()
df['Driving_experience']=df['Driving_experience'].replace('Unknown','5-10yr')

df['Driving_experience'].describe()
df['Driving_experience']=df['Driving_experience'].replace('Unknown','5-10yr')



# i had to clear it manually because sometimes the value is na ,unknown , cloud be another word but i didn't have time
# Out:
# /var/folders/1n/yqq3qhrn1nb3vy_qshmmw_n80000gn/T/ipykernel_5080/3558535310.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex_of_driver']=df['Sex_of_driver'].replace('Unknown','Male')
# /var/folders/1n/yqq3qhrn1nb3vy_qshmmw_n80000gn/T/ipykernel_5080/3558535310.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Educational_level']=df['Educational_level'].replace('Unknown','Junior high school')
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8439 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         8439 non-null   object
#  1   Day_of_week                  8439 non-null   object
#  2   Age_band_of_driver           8439 non-null   object
#  3   Sex_of_driver                8439 non-null   object
#  4   Educational_level            8439 non-null   object
#  5   Vehicle_driver_relation      8439 non-null   object
#  6   Driving_experience           8439 non-null   object
#  7   Type_of_vehicle              8439 non-null   object
#  8   Owner_of_vehicle             8439 non-null   object
#  9   Area_accident_occured        8439 non-null   object
#  10  Lanes_or_Medians             8439 non-null   object
#  11  Road_allignment              8439 non-null   object
#  12  Types_of_Junction            8439 non-null   object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  8439.000000           8439.000000
# mean                      2.038038              1.547340
# std                       0.680789              1.014755
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.pairplot(df)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.histplot(df , x='Age_band_of_driver' , y='Type_of_vehicle' )
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Type_of_vehicle'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.pairplot(df)

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
